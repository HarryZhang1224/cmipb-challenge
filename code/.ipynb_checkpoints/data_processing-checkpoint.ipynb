# %%
library(data.table)
library(dplyr)

# %%
data <- readRDS("~/cmi-challenge/data/master_allData_batchCorrected.RDS")

# %%
data$subject_specimen %>%
    filter(dataset=="2023_dataset") -> challenge_meta
data$subject_specimen %>%
    filter(dataset!="2023_dataset") -> training_meta

# %%
write.csv(challenge_meta, file="~/cmi-challenge/data/challenge_metadata.csv")
write.csv(training_meta, file="~/cmi-challenge/data/training_metadata.csv")

# %%
data$
# Out:
#        468        469        470       471        472       475       476
# P13500  0.9665574  0.9581967 0.6477049  0.7329508 0.5390164 0.8326230 1.052623
# P10147  2.5281941  3.0620985 1.7844397  3.5431834 0.7922912 1.5117773 2.022841
# P13501  0.9722382  1.0608559 1.3037943  1.2061892 0.9987239 1.3779981 1.943172
# P02778  0.8610639  1.1139531 1.1772604  1.2240823 0.5705303 0.9665194 1.786030
# P10145 20.3370700 12.5798222 6.9702358 15.2980286 2.9145729 0.8426749 2.339389
# P09919  1.6599553  2.0134228 2.3803132  1.6554810 1.3288591 1.1722595 2.062640
# P01563  0.6303030  1.2363636 1.1515152  1.4909091 0.9515152 0.5636364 1.224242
# P01579  2.7980727  5.0486202 3.4148051  4.1664477 2.8506351 0.4213754 3.112571
# P22301  1.2065728  1.5117371 1.2018779  1.7558685 0.8920188 0.7417840 1.375587
# P18510  1.7258719  1.7112733 1.3390105  2.0811030 0.8799676 0.7356042 1.437956
# P60568  1.2170475  1.0623902 1.1871705  1.2934974 0.8260105 1.2636204 1.621265
# P05231  1.8212291  3.2402235 2.1787709  1.7318436 1.2625698 0.6927374 1.698324
# P13232  1.8452279  1.6560619 1.4428203  1.7489252 1.0472915 0.6534824 1.465176
# P01375  2.2133621  1.2025862 1.0043103  1.8448276 0.7004310 0.9849138 1.818966
#        477       478       479       ⋯ 1014      1417       1206
# P13500 0.9965574 0.6532787 0.6265574 ⋯ 1.6187420 1.45039778  1.1668938
# P10147 1.9414704 0.6238401 0.2226981 ⋯ 4.6169679 0.78012048  1.0537149
# P13501 1.9338908 1.3055989 0.7319290 ⋯ 2.8655385 0.60375296 56.2312646
# P02778 1.2616417 1.1232155 0.3834126 ⋯ 5.2237632 2.92372093  0.5134461
# P10145 1.9899497 0.5427136 0.2280634 ⋯ 3.0573895 0.04850178  0.4489589
# P09919 2.2192394 1.1767338 0.8456376 ⋯ 1.8508093 0.91907108  1.1344124
# P01563 1.1212121 1.0060606 0.5878788 ⋯ 0.9519774 1.17796610  0.7146893
# P01579 3.3061761 1.0652650 1.5260622 ⋯ 0.1445147 0.54692953  0.2924252
# P22301 1.0845070 0.9154930 0.5070423 ⋯ 1.7394451 0.97225573  0.8468034
# P18510 1.2952149 0.8004866 0.4355231 ⋯ 2.8117428 1.36067102  0.8578751
# P60568 1.7768014 1.1177504 0.6353251 ⋯ 1.3543962 1.03512783  1.5131989
# P05231 1.0726257 0.6703911 0.5698324 ⋯ 2.6893939 0.89393939  0.8977273
# P13232 1.3138435 0.8959587 0.3611350 ⋯ 2.7184553 0.84957342  1.0731926
# P01375 1.4504310 0.9870690 0.5452586 ⋯ 1.5229662 0.58107360  0.7216381
#        1074       962        977        1276       1107       1392
# P13500  1.5068349 2.56217309  0.9691882  1.2738781  2.3744890  2.4420025
# P10147  8.9006024 2.36445783  1.7916667  2.4352410 19.5898594  1.9181727
# P13501  0.8909696 0.52612429 56.1248067 56.3218895  0.9275312  0.9614144
# P02778  4.9901903 2.51864693  0.5853277  1.5645666  4.9479070  3.5123044
# P10145  2.1990858 1.51142712  1.0837989  2.7943118 18.9659726 15.8852209
# P09919  1.8902182 2.34342013  1.3103448  1.5158339  3.7494722  2.0731879
# P01563  3.9661017 0.92937853  0.8559322  1.6525424  4.4067797  7.0480226
# P01579  0.3282709 0.06301292  0.4798132  0.9214225  0.6629563  2.3058202
# P22301  6.5645356 1.17249698  0.8757539  1.6887817  9.1290712  7.4571773
# P18510  2.8317801 1.29776328  1.0293569  1.8136067  3.1346692  1.8010252
# P60568  1.8345458 0.88671794  1.5190189  2.6518395  2.1147371  1.1207649
# P05231  2.2840909 1.11363636  1.5757576  2.6174242  8.0984848  1.4886364
# P13232  2.6430175 1.10462506  1.3524921  2.7471935  6.3313875  1.2590930
# P01375 13.1909242 1.12119535  1.2152739  1.5506364  8.8046486 14.6220255
#        1339
# P13500 0.6512241
# P10147 0.4472892
# P13501 0.5724877
# P02778 0.7140381
# P10145 0.1645505
# P09919 0.4067558
# P01563 0.7316384
# P01579 3.2376191
# P22301 0.7165259
# P18510 0.7977633
# P60568 0.3180212
# P05231 0.6515152
# P13232 0.8890885
# P01375 0.4382955

# %%
gene_exp_training <- data$pbmc_gene_expression$tpm$batchCorrected_data[, intersect(colnames(data$pbmc_gene_expression$tpm$batchCorrected_data), training_meta$specimen_id)]

# %%
write.csv(as.matrix(gene_exp_training), file="~/cmi-challenge/data/gene_exp_training_dataset.csv", row.names=TRUE)

# %%
write.csv(as.matrix(data$plasma_ab_titer$batchCorrected_data), file="~/cmi-challenge/data/IgG.csv", row.names=TRUE)

# %%
write.csv(as.matrix(data$pbmc_cell_frequency$batchCorrected_data), file="~/cmi-challenge/data/cell_freq.csv", row.names=TRUE)

# %%
challenge_meta %>%
    group_by(subject_id) %>%
    summarize(tp=paste(timepoint, collapse=",")) %>%
    pull(tp) %>%
    unique(.)
# Out:
# [1] "-30,-14,0"

# %%
training_meta %>%
    filter(timepoint %in% c(-30, -14, 0))
# Out:
#     specimen_id subject_id dataset      timepoint infancy_vac biological_sex
# 1     1          1         2020_dataset 0         wP          Female
# 2    11          2         2020_dataset 0         wP          Female
# 3    19          3         2020_dataset 0         wP          Female
# 4    27          4         2020_dataset 0         wP          Male
# 5    37          5         2020_dataset 0         wP          Male
# 6    45          6         2020_dataset 0         wP          Female
# 7    55          7         2020_dataset 0         wP          Female
# 8    63          8         2020_dataset 0         wP          Female
# 9    70          9         2020_dataset 0         aP          Male
# 10   77         10         2020_dataset 0         wP          Female
# 11   87         11         2020_dataset 0         wP          Female
# 12   96         12         2020_dataset 0         wP          Male
# 13  102         13         2020_dataset 0         aP          Male
# 14  109         14         2020_dataset 0         wP          Male
# 15  114         15         2020_dataset 0         wP          Male
# 16  121         16         2020_dataset 0         wP          Female
# 17  131         17         2020_dataset 0         wP          Female
# 18  138         18         2020_dataset 0         aP          Female
# 19  146         19         2020_dataset 0         wP          Male
# 20  153         20         2020_dataset 0         wP          Female
# 21  160         21         2020_dataset 0         wP          Male
# 22  167         22         2020_dataset 0         wP          Female
# 23  174         23         2020_dataset 0         wP          Female
# 24  181         24         2020_dataset 0         wP          Female
# 25  191         25         2020_dataset 0         wP          Female
# 26  201         26         2020_dataset 0         wP          Female
# 27  208         27         2020_dataset 0         aP          Female
# 28  216         28         2020_dataset 0         wP          Male
# 29  223         29         2020_dataset 0         aP          Male
# 30  232         30         2020_dataset 0         wP          Female
# ⋮   ⋮           ⋮          ⋮            ⋮         ⋮           ⋮
# 109 790         103        2022_dataset -30       wP          Female
# 110 792         103        2022_dataset   0       wP          Female
# 111 800         104        2022_dataset -30       wP          Female
# 112 802         104        2022_dataset   0       wP          Female
# 113 809         105        2022_dataset -30       wP          Female
# 114 811         105        2022_dataset   0       wP          Female
# 115 819         106        2022_dataset -30       aP          Female
# 116 821         106        2022_dataset   0       aP          Female
# 117 829         107        2022_dataset -30       aP          Female
# 118 831         107        2022_dataset   0       aP          Female
# 119 839         108        2022_dataset -30       wP          Female
# 120 841         108        2022_dataset   0       wP          Female
# 121 849         109        2022_dataset -30       wP          Female
# 122 851         109        2022_dataset   0       wP          Female
# 123 859         110        2022_dataset -30       aP          Female
# 124 861         110        2022_dataset   0       aP          Female
# 125 869         111        2022_dataset -30       wP          Male
# 126 871         111        2022_dataset   0       wP          Male
# 127 879         112        2022_dataset -30       aP          Male
# 128 882         112        2022_dataset   0       aP          Male
# 129 890         114        2022_dataset -30       wP          Male
# 130 892         114        2022_dataset   0       wP          Male
# 131 900         115        2022_dataset -30       aP          Female
# 132 902         115        2022_dataset   0       aP          Female
# 133 910         116        2022_dataset -30       aP          Male
# 134 912         116        2022_dataset   0       aP          Male
# 135 920         117        2022_dataset -30       aP          Female
# 136 922         117        2022_dataset   0       aP          Female
# 137 930         118        2022_dataset -30       aP          Male
# 138 932         118        2022_dataset   0       aP          Male
#     date_of_boost
# 1   2016-09-12
# 2   2019-01-28
# 3   2016-10-10
# 4   2016-08-29
# 5   2016-08-29
# 6   2016-10-10
# 7   2016-11-07
# 8   2019-02-25
# 9   2016-07-25
# 10  2016-07-25
# 11  2016-08-29
# 12  2016-07-25
# 13  2016-07-25
# 14  2016-08-15
# 15  2016-08-15
# 16  2016-07-25
# 17  2016-09-12
# 18  2016-08-29
# 19  2016-09-26
# 20  2016-08-29
# 21  2016-08-29
# 22  2016-08-29
# 23  2016-09-26
# 24  2016-09-13
# 25  2016-09-13
# 26  2016-09-26
# 27  2016-09-26
# 28  2016-09-26
# 29  2016-09-26
# 30  2016-09-26
# ⋮   ⋮
# 109 2021-09-07
# 110 2021-09-07
# 111 2021-09-07
# 112 2021-09-07
# 113 2021-09-07
# 114 2021-09-07
# 115 2021-09-07
# 116 2021-09-07
# 117 2021-09-07
# 118 2021-09-07
# 119 2021-09-27
# 120 2021-09-27
# 121 2021-09-27
# 122 2021-09-27
# 123 2021-09-27
# 124 2021-09-27
# 125 2021-10-18
# 126 2021-10-18
# 127 2021-10-18
# 128 2021-10-18
# 129 2021-10-18
# 130 2021-10-18
# 131 2021-11-01
# 132 2021-11-01
# 133 2021-11-29
# 134 2021-11-29
# 135 2021-11-29
# 136 2021-11-29
# 137 2022-01-24
# 138 2022-01-24
